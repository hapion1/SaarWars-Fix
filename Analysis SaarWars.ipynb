# %% [markdown]
# Abfolge der Tabellen
# 1. KBA weiblich
# 2. KBA männlich
# 3. Rocklands weiblich
# 4. Rocklands männlich
# 5. Olymp weiblich
# 6. Olymp männlich

# %%
import pandas as pd
from IPython import display
from datetime import datetime

print(f'letzter Durchlauf: {datetime.now()}')

table = pd.read_html('https://climbercontest.de/SaarWars/contest.php')

for dataframe in table:
    with pd.option_context('display.max_rows', 7):
        display.display(dataframe)

dupl_participants = 0
for df in table:
    dupl_participants += len(df)
print(f'Total participants including duplicates = {dupl_participants}')
# Out:
# letzter Durchlauf: 2022-07-05 17:12:41.624674
#      0                  1       2
# 0    1         Mia Siegel  122 P.
# 1    2       Julia Thietz  113 P.
# 2    3    Isabelle Kammer  112 P.
# ..  ..                ...     ...
# 76  49  Isabelle Neuhardt    0 P.
# 77  49    Daniela Glößner    0 P.
# 78  49        Laura Petri    0 P.
#
# [79 rows x 3 columns]
#        0               1       2
# 0      1      Hans Dampf  173 P.
# 1      2     Nils Siegel  172 P.
# 2      3   Tarnik Weinem  165 P.
# ..   ...             ...     ...
# 172  112   Tobias Müller    0 P.
# 173  112   Cyrill Wagner    0 P.
# 174  112  Nicolas Welsch    0 P.
#
# [175 rows x 3 columns]
#      0                1       2
# 0    1   Carlotta Barth  125 P.
# 1    2   Katharina Wolf  110 P.
# 2    3   Rebecca Praass  100 P.
# ..  ..              ...     ...
# 67  53     Anita Backes    0 P.
# 68  53      Diana Hocke    0 P.
# 69  53  Michelle Reuter    0 P.
#
# [70 rows x 3 columns]
#        0                 1       2
# 0      1         Luca Kaul  176 P.
# 1      2  David Springborn  166 P.
# 2      3        Lucas Marx  164 P.
# ..   ...               ...     ...
# 145  114      Andreas Pohl    0 P.
# 146  114   Lukas Kraushaar    0 P.
# 147  114   Oliver Heinrich    0 P.
#
# [148 rows x 3 columns]
#      0                    1       2
# 0    1           Julia Jene  136 P.
# 1    2           Sarah Braß  119 P.
# 2    3        Lucie Molitor  104 P.
# ..  ..                  ...     ...
# 43  37  Anne-Kathrin Küttel    0 P.
# 44  37   Katharina Buchthal    0 P.
# 45  37      Verena Wittling    0 P.
#
# [46 rows x 3 columns]
#      0             1       2
# 0    1   Gregor Lotz  164 P.
# 1    2    Paul Klein  162 P.
# 2    3   Leon Scholl  160 P.
# ..  ..           ...     ...
# 89  57   Pascal Koch    0 P.
# 90  57  Eduard Rakin    0 P.
# 91  57    David Huth    0 P.
#
# [92 rows x 3 columns]
# Total participants including duplicates = 610

# %%
# check duplicates
final_tables = []
duplicate_list = []
num = 0

for tables in table:
    indices_of_duplicates = []
    #temp = tables.drop(labels=[0, 2], axis=1) <== ersetzt durch (subset=1) Spezifikation
    temp = tables.copy()
    copy = temp.duplicated(subset=1)

    for index, dupl_value in copy.iteritems(): # iterate over pd.Series
        if dupl_value: # check if value at index is duplicate
            indices_of_duplicates.append(index)

    duplicate_list.append(temp.iloc[indices_of_duplicates]) # --> eckige klammern müssen benutzt werden bruh
    temp = temp.drop_duplicates(subset=1)
    final_tables.append(temp)
    num += len(indices_of_duplicates)
    
print(f'folgende Kandidaten können Duplikate sein ({num} Stück): ')

for dataframe in duplicate_list:
    with pd.option_context('display.max_rows', None):
        dataframe = pd.DataFrame(dataframe)
        display.display(dataframe)

# generate .csv files with duplicates per gym / gender(m or f)
l = ['kba_f', 'kba_m', 'rocklands_f', 'rocklands_m', 'olymp_f', 'olymp_m']
i = 0
for df in duplicate_list:
    df.to_csv(f'./{l[i]}.csv')
    i += 1
# Out:
# folgende Kandidaten können Duplikate sein (14 Stück):
#      0             1     2
# 52  49    Hannah Mai  0 P.
# 73  49  Marie Wolter  0 P.
#        0                   1     2
# 126  112        Paul Bungert  0 P.
# 128  112        Mark Scherer  0 P.
# 129  112         Jannik Feld  0 P.
# 131  112  Till Schmelczyrsch  0 P.
#      0                 1     2
# 56  53  Jamie Kockelmann  0 P.
#        0                1     2
# 114  114        Robin Neu  0 P.
# 118  114       Uwe Schohl  0 P.
# 123  114       Lucas Marx  0 P.
# 139  114     Moritz Huber  0 P.
# 140  114  Michael Schirra  0 P.
# Empty DataFrame
# Columns: [0, 1, 2]
# Index: []
#      0                      1     2
# 56  57       Sebastian Gerber  0 P.
# 77  57  Johannes Schwitzgebel  0 P.

# %%
# for dataframe in final_tables:
#     with pd.option_context('display.max_rows', None):
#         display.display(dataframe)

print(f'Total participants KBA = {len(final_tables[0]) + len(final_tables[1])} \nKBA women = {len(final_tables[0])} \nKBA men =  {len(final_tables[1])}')
print('----------')
print(f'Total participants Rocklands = {len(final_tables[2]) + len(final_tables[3])} \nRocklands women = {len(final_tables[2])} \nRocklands men =  {len(final_tables[3])}')
print('----------')
print(f'Total participants Olymp = {len(final_tables[4]) + len(final_tables[5])} \nOlymp women = {len(final_tables[4])} \nOlymp men =  {len(final_tables[5])}')

total_participants = 0
for df in final_tables:
    total_participants += len(df)

print('----------')
print(f'Total number of participants = {total_participants}')
dupl = dupl_participants - total_participants
print(f'Difference between totals = {dupl}')
print(f'ggf. fehlendes Geld = {dupl * 5}€')
# Out:
# Total participants KBA = 248
# KBA women = 77
# KBA men =  171
# ----------
# Total participants Rocklands = 212
# Rocklands women = 69
# Rocklands men =  143
# ----------
# Total participants Olymp = 136
# Olymp women = 46
# Olymp men =  90
# ----------
# Total number of participants = 596
# Difference between totals = 14
# ggf. fehlendes Geld = 70€

# %%
# get some analytics

# type(final_tables) == list(DataFrame)
# create sorted total male /female tables
male_table = pd.DataFrame([])
female_table = pd.DataFrame([])
i = 0

for table in final_tables:
    values = []
    for value in table[2]:
        value = int(value.split(' ')[0])
        values.append(value)
    table.drop(2, axis=1, inplace=True)
    table[2] = values
    if i == 0:
        female_table = table
    elif i == 1:
        male_table = table
    elif i % 2 == 0:
        female_table = pd.concat([female_table, table])
    else:
        male_table = pd.concat([male_table, table])
    i += 1


# Hallenpunkte Rangliste
def get_gym_points():
    # Laufvariable
    i = 0
    # für Hallenpunkte -> Dictionary
    points = {'KBA':0, 'Olymp':0, 'Rocklands':0}
    
    # test
    #final_tables[0] = final_tables[0].head()
    #print(f'{final_tables[0] = }')

    for table in final_tables:
        values = []
        # table[2] = Spalte, wo Punkte drinstehen
        for value in table[2]:
            #value = int(value.split(' ')[0]) --> unnötig, da bereits vorher in int umgewandelt
            values.append(value)
        
        if i == 0 or i == 1:
            points['KBA'] += sum(values)
        elif i == 2 or i == 3:
            points['Rocklands'] += sum(values)
        elif i == 4 or i == 5:
            points['Olymp'] += sum(values)
        
        i += 1

    temp = list(points.values())
    temp.sort()
    diff = temp[-1] - temp[-2]

    print(f'Difference between first and second = {diff}')
    print(f'The current gym-point-standings are the following: ')
    display.display(points)

# %%
for t in [female_table, male_table]:
    t.sort_values(by=[2], inplace=True, ascending=False)
    t.reset_index(inplace=True, drop=True)

def print_top(n:int):
    print(f'Top {n} female participants from all gyms:')
    display.display(female_table.iloc[:n])

    print(f'Top {n} male participants from all gyms:')
    display.display(male_table.iloc[:n])

print_top(35)
# Out:
# Top 35 female participants from all gyms:
#      0                    1    2
# 0    1           Julia Jene  136
# 1    1       Carlotta Barth  125
# 2    1           Mia Siegel  122
# 3    2           Sarah Braß  119
# 4    2         Julia Thietz  113
# 5    3      Isabelle Kammer  112
# 6    2       Katharina Wolf  110
# 7    3        Lucie Molitor  104
# 8    4       Luna Friedrich  103
# 9    5     Adeline Hehetror  101
# 10   3       Rebecca Praass  100
# 11   6        Tamina Lorenz   96
# 12   4     Natascha Klicker   95
# 13   7  Michaela Meisberger   91
# 14   8      Matilda Krauser   90
# 15   5        Jana Fromberg   88
# 16   6        Jennifer Soma   86
# 17   7         Marie Rauber   85
# 18   4      Michelle Keller   84
# 19   5     Hannah Rheinwald   83
# 20   8          Jenny Engel   82
# 21   8       Yasmine Briefs   82
# 22   9       Nina Engelkamp   82
# 23  10       Anna-Lena Wolf   81
# 24  10          Svenja Pohl   80
# 25  11         Maren Schohl   79
# 26   6          Lisa Koenen   79
# 27  11         Pauline Ruth   77
# 28  11         Julia Wagner   77
# 29  12      Alice Oberacker   77
# 30   7         Laura Weiter   76
# 31  13     Leandra Schiller   76
# 32   8          Jule Wollny   75
# 33  14      Charmaine Utzig   75
# 34  13          Myriam Betz   74
# Top 35 male participants from all gyms:
#      0                     1    2
# 0    1             Luca Kaul  176
# 1    1            Hans Dampf  173
# 2    2           Nils Siegel  172
# 3    2      David Springborn  166
# 4    3         Tarnik Weinem  165
# 5    3            Lucas Marx  164
# 6    1           Gregor Lotz  164
# 7    2            Paul Klein  162
# 8    4            jens vogel  161
# 9    3           Leon Scholl  160
# 10   5          Mika Scherer  157
# 11   4        Finn Machwirth  152
# 12   5          Patrick Igel  149
# 13   6    Bastian Meisberger  149
# 14   6        Samuel Schirra  147
# 15   6          Marko Boever  147
# 16   6           Jens Malter  147
# 17   4         Justus Eichel  146
# 18   7  Sebastian Rheinemann  146
# 19   9           Lutz Sänger  145
# 20   8   Hendrik Junkawitsch  145
# 21   5         Elias Weisser  142
# 22   6        Simon Andresen  141
# 23  10          Bernd Möller  141
# 24  11           Sascha Soma  138
# 25  11          Sam Williams  138
# 26   9        Chris Braeunig  138
# 27  10          Tobias Lesch  137
# 28  13     Max Rausch-Dupont  137
# 29  13             Scott Neu  137
# 30  10  Herribert Schnicolay  137
# 31  12           Jan Piontek  136
# 32  15        Marcel Lachnit  135
# 33  13        Richard Peifer  135
# 34  14           Steffen Mai  133

# %%
get_gym_points()
# Out:
# Difference between first and second = 613
# The current gym-point-standings are the following:
# {'KBA': 10589, 'Olymp': 5764, 'Rocklands': 9976}

# %% [markdown]
# Folgender Code ist nicht mehr für die Analyse relevant

# %%
# add id as index
df_complete = pd.concat(final_tables)

# generate ids
ids = list(range(0, len(df_complete)))
df_complete.insert(loc=0, column='id', value=ids)
df_complete = df_complete.set_index('id')

# export as json
df_complete.to_json(path_or_buf='./Teilnehmer.json')

#with pd.option_context('display.max_rows', None):
#    display.display(df_complete)

df_json = pd.read_json('./Teilnehmer.json')
df_json = df_json.sort_index()

# export as sorted json
df_json.to_json(path_or_buf='./Teilnehmer_final.json')

df_new_json = pd.read_json('./Teilnehmer_final.json')
with pd.option_context('display.max_rows', None):
    display.display(df_json)
# Out:
#        0                             1    2
# 0      1                    Mia Siegel  122
# 1      2                  Julia Thietz  113
# 2      3               Isabelle Kammer  112
# 3      4                Luna Friedrich  103
# 4      5              Adeline Hehetror  101
# 5      6                 Tamina Lorenz   96
# 6      7           Michaela Meisberger   91
# 7      8               Matilda Krauser   90
# 8      9                Nina Engelkamp   82
# 9     10                   Svenja Pohl   80
# 10    11                  Julia Wagner   77
# 11    11                  Pauline Ruth   77
# 12    13                   Myriam Betz   74
# 13    14                      Lea Görg   71
# 14    15                    Hannah Mai   67
# 15    15                 Stefanie Dohm   67
# 16    17                   Louise Betz   62
# 17    18                  Marion Engel   55
# 18    18                 Jana Waldmann   55
# 19    20                  Lisa Deckarm   53
# 20    21                   Luise Kempf   52
# 21    22                 Denise Däuber   50
# 22    23               Daniela Fischer   49
# 23    24                Amélie Clemens   48
# 24    24                   Lara Köhler   48
# 25    26                  Valerie Feis   43
# 26    27                Theresa Müller   41
# 27    28               Sarah Brettnich   39
# 28    28                 Marlene Fries   39
# 29    30              Adriana Altpeter   37
# 30    31              Vanessa Daschner   36
# 31    31                  Maike Zimmer   36
# 32    33              Elena Kurtzemann   35
# 33    34                  Nina Stadler   33
# 34    35             Hanna Niedermeier   28
# 35    35            Anna-Marie Schwarz   28
# 36    35                 Carlotta Hoff   28
# 37    38               Michaela Kremer   27
# 38    39           Amélie Müller Pinto   21
# 39    40              Sandra Rodríguez   17
# 40    41               Louisa Bachofen   16
# 41    42                 Cosima Hafner   15
# 42    43                Stephanie Höhn   14
# 43    44                   Nina Archut   11
# 44    45                    Paula Mohr    7
# 45    46            Leonie Wittenstein    6
# 46    47                 Rebecca Krier    4
# 47    48                  Verena Blank    1
# 48    49                  jessica hahn    0
# 49    49                  Marie Wolter    0
# 50    49                     Ida Stapf    0
# 51    49              Madeleine Birtel    0
# 52    49              Franca Kiefinger    0
# 53    49                      zoe moll    0
# 54    49           Zinzi Sarah Ngoumou    0
# 55    49                  Jessica Kamp    0
# 56    49                 Lauren naudin    0
# 57    49                  Eileen Klein    0
# 58    49             Viktoria Lima-Vaz    0
# 59    49                   Elena Weiss    0
# 60    49                 Josaine Prinz    0
# 61    49               Michaela Berger    0
# 62    49                Verena Roßbach    0
# 63    49                   Leila Funke    0
# 64    49              Katharina Jansen    0
# 65    49                  Sabrina Lang    0
# 66    49            Stephanie Hoffmann    0
# 67    49                   Conny Stopp    0
# 68    49           Katharina Schackmar    0
# 69    49                   Lena Kammer    0
# 70    49                 Eva Friedrich    0
# 71    49                 Paola Goergen    0
# 72    49                 Fabienne Hahn    0
# 73    49                sigrid cacspar    0
# 74    49             Isabelle Neuhardt    0
# 75    49               Daniela Glößner    0
# 76    49                   Laura Petri    0
# 77     1                    Hans Dampf  173
# 78     2                   Nils Siegel  172
# 79     3                 Tarnik Weinem  165
# 80     4                    jens vogel  161
# 81     5                  Mika Scherer  157
# 82     6            Bastian Meisberger  149
# 83     7          Sebastian Rheinemann  146
# 84     8           Hendrik Junkawitsch  145
# 85     9                Chris Braeunig  138
# 86    10                  Tobias Lesch  137
# 87    10          Herribert Schnicolay  137
# 88    12                   Jan Piontek  136
# 89    13                Richard Peifer  135
# 90    14                   Steffen Mai  133
# 91    15                   Yoshua Haas  132
# 92    16                   Lars Proske  128
# 93    17                     Paul Mohr  126
# 94    18              Maximilian Klose  125
# 95    19                Michael Becker  124
# 96    19                Marvin Stenger  124
# 97    21                 Kevin Küsters  123
# 98    21              Frank Steinacker  123
# 99    23             Savitskiy Timofiy  119
# 100   24            Savitskiy Olexandr  118
# 101   25               Bananenbauer Jo  117
# 102   26                 Aaron Schwarz  116
# 103   27             Kay Uwe Buschauer  110
# 104   28               Demian Dietrich  109
# 105   29                    Ruwen Jost  108
# 106   30                   Jonas Maier  107
# 107   30                 Oliver Bürtel  107
# 108   32                Nikolas Eckert  103
# 109   32              Dennis Machwirth  103
# 110   34                   Jens Harder  102
# 111   35                Stefan Stonjek  101
# 112   36        The old man Bouldering   96
# 113   36                Johannes Mertz   96
# 114   38                  Fynn Krauser   95
# 115   39                    Marco Dohm   91
# 116   40             Andreas Leibfried   90
# 117   41                 Martin Jacobs   89
# 118   42              Alexander Dahmen   88
# 119   43               Dirk Leinenbach   86
# 120   44                     Max Jakob   84
# 121   45                    Jan Backes   83
# 122   46                  Paul Bungert   81
# 123   47                    Karl Jakob   76
# 124   48                  Jakob Holzer   75
# 125   48              Sebastian Dahmen   75
# 126   50                  Michael Höhn   74
# 127   50               Albert Marekfia   74
# 128   52                 daniel kemper   72
# 129   53                Sebastian Adam   71
# 130   53                  Oskar Ludwig   71
# 131   55                Philipp Hermes   70
# 132   56                   Till Mertin   69
# 133   56                Michael Kasper   69
# 134   58                Adrian Gerling   67
# 135   58                 Markus Müller   67
# 136   60              Christopher Jung   66
# 137   61                  Kevin Michel   65
# 138   62             Christian Schmidt   64
# 139   63                 Jan Machwirth   63
# 140   64             Johannes Richters   62
# 141   65            Daniel Gusenburger   59
# 142   66               Frederic Zenner   58
# 143   67                 Oliver Däuber   57
# 144   68                  Daniel Dietz   56
# 145   69               Christoph Pauly   55
# 146   69                 Peter Krauser   55
# 147   71                   Joel Schanz   54
# 148   72                  Kevin Leinen   50
# 149   73                  Kevin Klesen   49
# 329   13                     Scott Neu  137
# 330   13             Max Rausch-Dupont  137
# 331   15                Marcel Lachnit  135
# 332   16                     Tom Weber  130
# 333   17                 Pinky The Kid  122
# 334   17                Thomas Schweiß  122
# 335   19                 Jörg Schallmo  119
# 336   20                 Felix Klicker  118
# 337   21                   Thomas Kraß  116
# 338   21                 Aleks Schmidt  116
# 339   23                   Leon Horras  112
# 340   24                Alexander Bick  111
# 341   25                     Til Klein  108
# 342   26           Jonas Stillenmunkes  104
# 343   27             Christian Wegmann  102
# 344   28               Frowin Susewind  100
# 345   28                  Fynn Klicker  100
# 346   30                  Chris Brüske   99
# 347   31                 Felix Smarsly   98
# 348   32               Florian Scherer   97
# 349   33                 Leon Kornfeld   95
# 350   34            Christian Klaassen   94
# 351   35                  Sascha Ernst   93
# 352   36                  Florian Kamp   91
# 353   37                  Nils Lambert   87
# 354   37              Tim Scheckenbach   87
# 355   37               Michael Schirra   87
# 356   40                  Timo Brücker   86
# 357   41                  Hendrik Bock   85
# 358   42                Maxime Schwenk   83
# 359   43               Benjamin jochum   80
# 360   43                  Thomas Barth   80
# 361   45                Felix Cullmann   79
# 362   45                    Nico Fries   79
# 363   47                Michael Szulik   76
# 364   48                  Eric Spaniol   73
# 365   49             Alexander Baldauf   71
# 366   49    tättoowierter assi l`hoste   71
# 367   49              Bastian DIllmann   71
# 368   52               Felix Steinmetz   70
# 369   53                   Luca Lorang   67
# 370   54                  Jason Bourne   66
# 371   55  Climb Master Flash Vögelchen   65
# 372   56                Florian Maurer   64
# 373   57               Lukas Buschauer   63
# 374   57                 Johannes Kraß   63
# 375   57               Pascal Burkholz   63
# 376   60                 Nils Hörnlein   60
# 377   60          Alessandro Diederich   60
# 378   62                 Moritz Schnur   58
# 379   63                 Bastian Jäger   56
# 380   64                    Henry Junk   55
# 381   65                 Hannes Köther   54
# 382   66                  Lukas Eckert   49
# 383   67                    Maik Schuh   48
# 384   68            Manuel Recktenwald   47
# 385   69                 Tobias Bohlen   46
# 386   69               Frederic Backes   46
# 387   71                  Jens Kreisel   45
# 388   72               Ronald Polensak   42
# 389   73                  Jenso Maroni   41
# 390   74                  Fabian Schön   37
# 391   75                   Dirk Rauber   36
# 392   76                   Ravn Welsch   33
# 393   77      Javier Matias Echeverria   32
# 394   77                   Joscha Kunz   32
# 395   77                Patrick Geibel   32
# 396   77                  Marius Feidt   32
# 397   81                 Christan Graf   28
# 398   81                   Linus Tritz   28
# 399   81                  Torsten Fuss   28
# 400   84                  Elias Li-Sai   27
# 401   84             Johannes Basenach   27
# 402   84                   Leon Marzen   27
# 403   87                    Uwe Schohl   26
# 404   87                  Samuel Fuchs   26
# 405   89                 Tiago Altmann   25
# 406   89                  Emanuel Wolf   25
# 407   91                   Robin Ludes   22
# 408   92                     Robin Neu   21
# 409   93                   Jonas Brill   20
# 410   93                   David Colle   20
# 411   95                   Philip Neis   19
# 412   95                   Frank Turra   19
# 413   97                  Niclas Rolle   18
# 414   98                Tamino Altmann   16
# 415   98                  Max Arweiler   16
# 416  100                Felix Philippi   15
# 506    1                   Gregor Lotz  164
# 507    2                    Paul Klein  162
# 508    3                   Leon Scholl  160
# 509    4                 Justus Eichel  146
# 510    5                 Elias Weisser  142
# 511    6                Simon Andresen  141
# 512    7                  Marc Schröer  133
# 513    8               Michael Kormann  129
# 514    9              Dominik Neuhardt  128
# 515   10                 Connor Johann  121
# 516   11                 Georg Friedel  108
# 517   12            Sebastian Wendling  104
# 518   13                  Jan Buchholz  102
# 519   14                   Sven Maurer  100
# 520   15                   Jakob Spang   99
# 521   16             Alexander Ziebert   98
# 522   17                  Jan Utzinger   97
# 523   18             Marcel Schumacher   92
# 524   19              Thorsten Neufang   88
# 525   20               Phillipp Schulz   87
# 526   21                 Maik Kreutzer   85
# 527   22                    Julian Feß   83
# 528   23              Christoph Gamble   78
# 529   24                      Tom Puhl   77
# 530   25              Fabian Sauerbrey   75
# 531   26                Andreas Keller   74
# 532   27                Ludovic Basset   72
# 533   28                   Fabian Linn   68
# 534   29              Thorsten Schulze   62
# 535   30                  Philipp Drum   58
# 536   31                Daniel Mangold   55
# 537   32                   Kai Schröer   54
# 538   33                 Dennis Balzer   52
# 539   33                   Moritz Woll   52
# 540   35              Sebastian Gerber   50
# 541   36           Christian Sauerbrey   49
# 542   37            Alexander Scholtes   46
# 543   38               Frederik Birtel   45
# 544   39               Benjamin Högner   40
# 545   39                Daniel Kalcher   40
# 546   41                Moritz Schulze   35
# 547   42                   Oliver Heil   32
# 548   43              Dominik Theobald   31
# 549   43                  Lars Stephan   31
# 550   45                Christoph Bläs   26
# 551   45               Daniel Bachmann   26
# 552   47                Tobias Willian   23
# 553   48                    Stefan Fox   21
# 554   48             Alexander Potapov   21
# 555   50                    Dirk Flick   19
# 556   51            Johannes Metzinger   17
# 557   52            Mark-Phillip Rohde   14
# 558   53               Matthias Wagner    8
# 559   53                   Kevin Fleck    8
# 560   55                   Elric Fries    6
# 561   55                    Jules Prim    6
# 562   57               Rudolf Pankratz    0
# 563   57                 Steven Polzer    0
# 564   57                    Max Miosga    0
# 565   57                Nicolas Schaly    0
# 566   57            Thomas Berlinghoff    0
# 567   57                    Dennis Alt    0
# 568   57                     Jan Selau    0
# 569   57                    Jan Horter    0
# 570   57         Johannes Schwitzgebel    0
# 571   57                  Max Carlsson    0
# 572   57                 Andreas Lange    0
# 573   57                   Marco Hocke    0
# 574   57                   Jakob Mertz    0
# 575   57                   Jens Zimmer    0
# 576   57                  Jonas Schnur    0
# 577   57                      Max Eckl    0
# 578   57              Brian Weisgerber    0
# 579   57               Jonas Burkhardt    0
# 580   57             Christian Schönau    0
# 581   57                  Florian Hock    0
# 582   57                    Kevin Mees    0
# 583   57                      Tom Kehl    0
# 584   57                   Luca Nothof    0
# 585   57                    Nico Kmoch    0
# 586   57                 Tristan Weber    0
# 587   57                Edward Friedel    0
# 588   57               Philipp Schönau    0
# 589   57                  Mikka Rainer    0
# 590   57                  Marco Gerigk    0
# 591   57                  Hassan Iqbal    0
# 592   57                 Steven Jessel    0
# 593   57                   Pascal Koch    0
# 594   57                  Eduard Rakin    0
# 595   57                    David Huth    0
